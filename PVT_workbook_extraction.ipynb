# %% [markdown]
# # **Summary**

# %%
# ── Summary of Oil PVT Study Results ──────────────────────────────────────────────
# All pressures in psia, temperatures in °F, GOR in scf/STB, API in degrees
Well_Summary = {
    "well_name":       "NDI-OML-40 #22",
    "initial_pressure":  4089.7,   # psia  — initial reservoir pressure
    "initial_temp":      207.2,    # °F    — initial reservoir temperature
    "fluid_mol% C7+":             52.9,    # % - Reservoir fluid mol weight
    "fluid_mol_wt":     122.05,     # g/mol - Reservoir fluid mol weight
    "viscosity@initial_pressure":       0.989,     # cP - viscosity @ initial reservoir pressure @207.2°F
    "viscosity@Bp": 0.554,    # cP - viscosity @ Bubble point pressure @207.2°F
    }

# %%
CCE_Summary = {
    "Bubble point pressure":       988,   # psia  — bubble point pressure
    "Fluid type":  'Black oil',
    }

# %%
DLE_Summary = {
    "oil volume factor1":       1.173,    # bbl/stb @ initial reservoir pressure
    "solution GOR1":  261.5,   # scf/stb  — solution GOR @ initial reservoir pressure
    "fluid density1":      0.7567,    # g/cm3    — fluid density @ initial reservoir pressure
    "oil volume factor2":      1.217,     # bbl/stb @ bubble point pressure
    "solution GOR2":     261.5,     # scf/stb @ bubble point pressure
    "fluid density2":       0.7298,     # g/cm3 @ bubble point pressure
    "residual oil density2": 0.8205,    # g/cm3 -  @ 60°F
    "residual oil sg2": 0.8213,    #  - @ 60°F
    "API gravity 2": 40.79,    # °API -  @ 60°F

    }

# %% [markdown]
# # **Constant Composition Expansion (CCE)**

# %%
CCE = {
        "pressure":     [5500,5000,4500,4090,3500,3000,2500,2000,1500,988,800,600,400,200],  # psia
        "relative volume":     [0.9524,0.9563,0.9610,0.9645,0.9705,0.9758,0.9815,0.9873,0.9935,1.0000,1.1037,1.3147,1.7978,3.4162],
        "density":          [0.7663,0.7632,0.7595,0.7567,0.7520,0.7479,0.7436,0.7392,0.7346,0.7298,None,None,None,None],     # g/cm3
        "Y-function":     [None,None,None,None,None,None,None,None,None,None,2.2667,2.0547,1.8427,1.6307],    # -
        "compressibility": [8.320E-06,8.905E-06,9.477E-06,9.946E-06,1.060E-05,1.115E-05,1.169E-05,1.222E-05,1.274E-05,1.326E-05,None,None,None,None]   # 1/psia
        }

# %% [markdown]
# # **Differential Liberation Experiment (DLE)**

# %%
DLE = {
        "pressure":     [5500,5000,4500,4090,3500,3000,2500,2000,1500,988,800,600,400,200,100,15],  # psia
        "Rs":     [261.5,261.5,261.5,261.5,261.5,261.5,261.5,261.5,261.5,261.5,227.8,180.0,126.9,66.0,32.5,0.0],  # Scf/Stb
        "Bo":          [1.159,1.163,1.169,1.173,1.181,1.187,1.194,1.201,1.209,1.217,1.208,1.188,1.162,1.120,1.093,1.066],  # Bbl/Stb
        "Oil density":     [0.7663,0.7632,0.7595,0.7567,0.7520,0.7479,0.7436,0.7392,0.7346,0.7298,0.7353,0.7424,0.7502,0.7600,0.7654,0.7700],  # g/cm3
        "Bg": [None,None,None,None,None,None,None,None,None,None,0.0217,0.0292,0.0444,0.0899,0.1804,1.2233],  # cu ft/Scf
        "Gas Viscosity": [None,None,None,None,None,None,None,None,None,None,0.0139,0.0134,0.0128,0.0118,0.0106,0.0079],  # cP
        "Gas Density": [None,None,None,None,None,None,None,None,None,None,0.0450,0.0345,0.0244,0.0146,0.0095,0.0026],  # g/cc
        "Gas Z-factor": [None,None,None,None,None,None,None,None,None,None,0.9238,0.9327,0.9433,0.9554,0.9589,0.9752]
        }

# %% [markdown]
# # **Separator test**

# %%
seperator_test = {
        "test" :    ["1st Sep Test","2nd Sep Test","3rd Sep Test","4th Sep Test"],
        "pressure":     [215.0,130.0,102.0,65],                     # psia
        "temperature":     [90,90,90,90],                           # °F
        "total GOR":      [240.5,233.78,233.24,238.28],             # scf/STB
        "stock tank API":     [42.08,42.25,42.27,42.14],            # °API
        "formation volume factor": [1.1819,1.1770,1.1766,1.1805]
        }

# %% [markdown]
# # **Optimum Sep & Adjusted PVT Parameters**
